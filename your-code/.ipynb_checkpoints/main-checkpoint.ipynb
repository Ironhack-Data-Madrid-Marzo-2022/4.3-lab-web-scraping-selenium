# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Selenium Doc](https://www.selenium.dev/documentation/)
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `Selenium` and `pandas` are imported for you.

# %%
# %pip install selenium
# %pip install webdriver_manager

import pandas as pd
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver


PATH=ChromeDriverManager().install()
driver=webdriver.Chrome(PATH)
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %% [markdown]
# #### Enable the options you may need. In the next cell you have an example of them but you can choose to use them or not.

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %% [markdown]
# #### Download, parse, and print the content from the Trending Developers page from GitHub:

# %%
url = 'https://github.com/trending/developers'
driver.get(url)

# %%
driver.find_element_by_tag_name('body').text[:100]
# Out:
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_13763/122985561.py:1: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   driver.find_element_by_tag_name('body').text[:100]
# 'Skip to content\nProduct\nTeam\nEnterprise\nExplore\nMarketplace\nPricing\nSign in\nSign up\nExplore\nTopics\nT'

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code

#copio el full Xpath                    #/html/body/div[4]/main/div[3]/div/div[2]/article[1]/div[2]/div[1]/div[1]/h1/a
nombre = driver.find_element_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[1]/div[2]/div[1]/div[1]/h1/a").text
                                      #/html/body/div[4]/main/div[3]/div/div[2]/article[2]/div[2]/div[1]/div[1]/h1/a
                                      # veo que lo que itera es el article[i]
nick = driver.find_element_by_xpath('/html/body/div[4]/main/div[3]/div/div[2]/article[1]/div[2]/div[1]/div[1]/p/a').text
                                    #/html/body/div[4]/main/div[3]/div/div[2]/article[3]/div[2]/div[1]/div[1]/p/a
print(nombre,nick)
# Out:
# Álvaro alvarotrigo
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/1238454723.py:4: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   nombre = driver.find_element_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[1]/div[2]/div[1]/div[1]/h1/a").text
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/1238454723.py:7: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   nick = driver.find_element_by_xpath('/html/body/div[4]/main/div[3]/div/div[2]/article[1]/div[2]/div[1]/div[1]/p/a').text

# %%
lista_nombres=[]
for i in range (1,25+1): 
    nombre = driver.find_element_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article["+str(i)+"]/div[2]/div[1]/div[1]/h1/a").text
    nick = driver.find_element_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article["+str(i)+"]/div[2]/div[1]/div[1]/p/a").text
    lista_nombres.append(nombre+ " " + "("+nick+")" )
    
lista_nombres
# Out:
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/701415070.py:3: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   nombre = driver.find_element_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article["+str(i)+"]/div[2]/div[1]/div[1]/h1/a").text
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/701415070.py:4: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   nick = driver.find_element_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article["+str(i)+"]/div[2]/div[1]/div[1]/p/a").text
# ['Álvaro (alvarotrigo)',
#  'Ariel Mashraki (a8m)',
#  'Marten Seemann (marten-seemann)',
#  'Boris Dayma (borisdayma)',
#  'Amruth Pillai (AmruthPillai)',
#  'Stefan Prodan (stefanprodan)',
#  'François Chollet (fchollet)',
#  "Bruno D'Luka (bdlukaa)",
#  'Pengfei Ni (feiskyer)',
#  'Aleksandr Bezobchuk (alexanderbez)',
# ...

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'
driver.get(url)

driver.find_element_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[1]/h1/a").text
# Out:
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/3128803698.py:5: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[1]/h1/a").text
# 'fighting41love / funNLP'

# %%
#your code
#ahora no se cuantos elementos hay.
numero_elementos= driver.find_element_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]")

numero_elementos=len(numero_elementos.find_elements_by_tag_name('article'))

for i in range(1, numero_elementos+1):
    print(driver.find_element_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article["+str(i)+"]/h1/a").text)
# Out:
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/3007769980.py:3: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   numero_elementos= driver.find_element_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]")
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/3007769980.py:8: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   print(driver.find_element_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article["+str(i)+"]/h1/a").text)
# fighting41love / funNLP
# Sjj1024 / QiangCai
# vinta / awesome-python
# lucidrains / DALLE2-pytorch
# mlcommons / inference
# Azure / azure-sdk-for-python
# locustio / locust
# cider-security-research / cicd-goat
# facebookresearch / mae
# donnemartin / system-design-primer
# huggingface / transformers
# jhao104 / proxy_pool
# facebookresearch / pytorch3d
# Rapptz / discord.py
# ...

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'
driver.get(url)

# %%
#your code
imagenes= driver.find_elements_by_tag_name('img')
for i in imagenes:
    print(i.get_attribute('src'))
# Out:
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/4093966300.py:2: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   imagenes= driver.find_elements_by_tag_name('img')
# https://upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png
# https://upload.wikimedia.org/wikipedia/en/thumb/8/8c/Extended-protection-shackle.svg/20px-Extended-protection-shackle.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python' 
driver.get(url)

# %%
#your code
imagenes= driver.find_elements_by_tag_name('a')
for i in imagenes:
    print(i.get_attribute('href'))
# Out:
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/1017538647.py:2: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   imagenes= driver.find_elements_by_tag_name('a')
# None
# https://en.wikipedia.org/wiki/Python#mw-head
# https://en.wikipedia.org/wiki/Python#searchInput
# https://en.wiktionary.org/wiki/Python
# https://en.wiktionary.org/wiki/python
# https://en.wikipedia.org/wiki/Pythonidae
# https://en.wikipedia.org/wiki/Python_(genus)
# https://en.wikipedia.org/wiki/Python#Computing
# https://en.wikipedia.org/wiki/Python#People
# https://en.wikipedia.org/wiki/Python#Roller_coasters
# https://en.wikipedia.org/wiki/Python#Vehicles
# https://en.wikipedia.org/wiki/Python#Weaponry
# https://en.wikipedia.org/wiki/Python#Other_uses
# https://en.wikipedia.org/wiki/Python#See_also
# https://en.wikipedia.org/w/index.php?title=Python&action=edit&section=1&editintro=Template:Disambig_editintro
# ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'
driver.get(url)

# %%
#your code
tabla_articulos = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[3]/div/div/div[1]')
tabla_articulos = tabla_articulos.find_elements_by_tag_name('div')
for i in tabla_articulos:
    if(i.get_attribute('class')) == "usctitlechanged":
        print (i.text)
# Out:
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/2891699971.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   tabla_articulos = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[3]/div/div/div[1]')
# Title 12 - Banks and Banking
# Title 19 - Customs Duties
# Title 22 - Foreign Relations and Intercourse

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'
driver.get(url)

# %%
#your code 
nombres= driver.find_elements_by_tag_name('h3')
for i in nombres:
    print(i.text)
# Out:
# RAFAEL CARO-QUINTERO
# YULAN ADONAY ARCHAGA CARIAS
# EUGENE PALMER
# BHADRESHKUMAR CHETANBHAI PATEL
# ALEJANDRO ROSALES CASTILLO
# ARNOLDO JIMENEZ
# JASON DEREK BROWN
# ALEXIS FLORES
# JOSE RODOLFO VILLARREAL-HERNANDEZ
# OCTAVIANO JUAREZ-CORRO
# FEDERAL BUREAU OF INVESTIGATION
# FBI.gov Contact Center
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/4003492797.py:2: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   nombres= driver.find_elements_by_tag_name('h3')

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

driver.get(url)

# %%
#your code
tabla_terre = driver.find_element_by_xpath('/html/body/div[1]/div[7]/table[2]/tbody')
tabla_row = tabla_terre.find_elements_by_tag_name("tr")
tabla=[]
for i in tabla_row:
    fila=[tr.text]
    
    """for j in i.find_elements_by_tag_name("td"):
        #if j.text not in ["",None,"F","1"]:
        fila.append(j.text)
            """
    tabla.append(fila)

tabla
# Out:
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/266712680.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   tabla_terre = driver.find_element_by_xpath('/html/body/div[1]/div[7]/table[2]/tbody')
# /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:359: UserWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   warnings.warn("find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead")
# [['2022-04-14   06:57:19.5\n09min ago',
#   '42.98 ',
#   'N  ',
#   '0.29 ',
#   'E  ',
#   '2',
#   '3.1',
#   ' PYRENEES'],
#  ['2022-04-14   06:55:02.0\n12min ago',
#   '36.37 ',
#   'N  ',
#   '9.90 ',
#   'W  ',
#   '29',
#   '2.4',
#   ' WEST OF GIBRALTAR'],
#  ['2022-04-14   06:48:34.0\n18min ago',
#   '31.34 ',
#   'S  ',
#   '67.49 ',
#   'W  ',
#   '89',
#   '3.2',
# ...

# %%
df=pd.DataFrame(tabla)
df
# Out:
#                                          0       1    2        3    4    5  \
# 0       2022-04-14   06:57:19.5\n09min ago  42.98   N      0.29   E      2
# 1       2022-04-14   06:55:02.0\n12min ago  36.37   N      9.90   W     29
# 2       2022-04-14   06:48:34.0\n18min ago  31.34   S     67.49   W     89
# 3       2022-04-14   06:48:17.0\n18min ago   7.16   S    105.90   E     10
# 4       2022-04-14   06:41:30.0\n25min ago   5.07   N     95.53   E     12
# 5       2022-04-14   06:33:40.7\n33min ago  33.36   N    116.36   W      2
# 6       2022-04-14   06:30:03.8\n36min ago  39.45   N     27.82   E     14
# 7       2022-04-14   06:26:16.0\n40min ago   7.08   S    106.06   E     10
# 8   2022-04-14   06:06:50.9\n1hr 00min ago  35.52   N      3.70   W     10
# 9   2022-04-14   06:04:19.0\n1hr 02min ago  36.67   S     73.49   W     22
# 10  2022-04-14   05:29:57.0\n1hr 37min ago  32.95   S     68.41   W     10
# ...

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'
driver.get(url)

# %%
#your code

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'
driver.get(url)

# %%
#your code
#/html/body/div[2]
grupo_idiomas = driver.find_element_by_xpath('/html/body/div[2]').find_elements_by_tag_name("div")



for i in grupo_idiomas:
    a = i.text.split(" ")
    print(a[0][:-1],int(a[0][-1]+a[1]+a[2][:3]))
# Out:
# Español
#  1755000
# English
#  6458000
# Русский
#  1798000
# 日本語
#  1314000
# Deutsch
#  2667000
# Français
#  2400000
# 中文
#  1256000
# Italiano
#  1742000
# Português
#  1085000
# Polski
#  1512000
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/658616309.py:3: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   grupo_idiomas = driver.find_element_by_xpath('/html/body/div[2]').find_elements_by_tag_name("div")

# %% [markdown]
# ### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'
driver.get(url)

# %%
#your code 
grupo_temas = driver.find_element_by_xpath("/html/body/div[3]/main/div[3]/div/ul").find_elements_by_tag_name("li")

for i in grupo_temas:
    print(i.find_element_by_tag_name("h3").text)
# Out:
# Business and economy
# Crime and justice
# Defence
# Education
# Environment
# Government
# Government spending
# Health
# Mapping
# Society
# Towns and cities
# Transport
# Digital service performance
# Government reference data
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/2227745399.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   grupo_temas = driver.find_element_by_xpath("/html/body/div[3]/main/div[3]/div/ul").find_elements_by_tag_name("li")
# /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:359: UserWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   warnings.warn("find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead")
# ...

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'
driver.get(url)

# %%
#your code               #/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody
lista_idiomas= driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody").find_elements_by_tag_name("tr")
tabla=[]

    
for i in range (11):
    fila=[]
    for j in lista_idiomas[i].find_elements_by_tag_name("td"):
        fila.append(j.text)
    tabla.append(fila)
tabla=pd.DataFrame(tabla)

tabla
# Out:
# /var/folders/90/gr77lgmd6713qz3vp27nwytc0000gn/T/ipykernel_6887/2502669198.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   lista_idiomas= driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody").find_elements_by_tag_name("tr")
#        0                                    1     2        3              4  \
# 0   None                                 None  None     None           None
# 1      1                     Mandarin Chinese   918  11.922%   Sino-Tibetan
# 2      2                              Spanish   480   5.994%  Indo-European
# 3      3                              English   379   4.922%  Indo-European
# 4      4  Hindi (sanskritised Hindustani)[11]   341   4.429%  Indo-European
# 5      5                              Bengali   300   4.000%  Indo-European
# 6      6                           Portuguese   221   2.870%  Indo-European
# ...

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'
driver.get(url)

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
